# %% [markdown]
# <a href="https://colab.research.google.com/github/matini93/daily/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#111

# %% [markdown]
# While문 기본 구조

# %%
for num in range(3):
  print("데이터",num)
# Out:
# 데이터 0
# 데이터 1
# 데이터 2

# %%
num = 0
while num< 3:
  print("데이터",num)
  num+=1
# Out:
# 데이터 0
# 데이터 1
# 데이터 2

# %% [markdown]
# 입력을 받는 방법

# %%
name = input("이름이 뭐에요?: ")
print(name,"안녕!")
# Out:
# 이름이 뭐에요?: 홍길동
# 홍길동 안녕!

# %% [markdown]
# 넘어가기와 멈추기

# %%
count = 0 
while count < 3 : 
  count +=1
  if count==2:
    continue
  print(count)
# Out:
# 1
# 3

# %%
count = 0 
while count < 3 : 
  count +=1
  if count ==2:
    break
  print(count)
# Out:
# 1

# %% [markdown]
# 무한 반복하기

# %%
while True:
  print("ii를 누르세요.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ii를 누르세요.
# ...

# %% [markdown]
# 3.15 연습문제 다음코드의 출력 결과를 적어보세요.

# %%
count = 0 
while count < 3 :
  print(count)
  count = count + 1
# Out:
# 0
# 1
# 2

# %% [markdown]
# 그림과 같은 실행화면을 출력하도록 빈칸을 채워보세요

# %%
count =1 
while count < 4 :
  count =  count + 1 
  print(count)
# Out:
# 2
# 3
# 4

# %%
count = 0 
while count <= 5:
  if count % 2 !=0:
    print(count)
  count +=1
# Out:
# 1
# 3
# 5

# %%
price = 0 
while price != -1:
  price = int(input("가격을 입력하세요(종료 : -1)"))

# %%
a = input("구구단 몇단을 계산할까? : ")

for j in range(1, 10):
    a = int(a)
    print(a,"x", j,"=",a*j)
# Out:
# 구구단 몇단을 계산할까? : 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45

# %% [markdown]
# 튜플은 변경할 수 없다.

# %%
a = (1,3,4,5,)
print(type(a))
#패킹과 언패킹
# Out:
# <class 'tuple'>

# %%
clovers = "클로버1", "클로버2", "클로버3"
print(clovers)
print(type(clovers))
# Out:
# ('클로버1', '클로버2', '클로버3')
# <class 'tuple'>

# %%
one, two, three = clovers
print(1,one,2,two,3,three)
# Out:
# 1 클로버1 2 클로버2 3 클로버3

# %% [markdown]
# 3.18 딕셔너리의 기본 구조

# %%
my_dict3 ={"과목명":"데이터마이닝","학기":"2022학년 가을학기","교수명":"고봉균","강의실":"자연대2호관 215호"}

# %%
import pandas as pd
df_1 = pd.DataFrame(my_dict3, index=[0])

# %%
df_1
# Out:
#       과목명           학기  교수명          강의실
# 0  데이터마이닝  2022학년 가을학기  고봉균  자연대2호관 215호

# %%
alice = {"성별":"여","나이":13,"혈액형":"AB"}

# %%
alice["나이"] = 14
print(alice["나이"])
# Out:
# 14

# %% [markdown]
# random 모듈
# random.choice

# %%
def my_func():
  print("실습을 해봅시다!")
  return
my_func()
# Out:
# 실습을 해봅시다!

# %%
def add(num1, num2):
  return num1 + num2
print(add(4,3))
# Out:
# 7

# %%
import random
subject = ["데이터","마이닝","및","실습"]
print(random.choice(subject))
print(random.sample(subject,2))
# Out:
# 마이닝
# ['데이터', '마이닝']

# %%
print(random.randint(1,100))
# Out:
# 12

# %%
#3.22 연습문제 
def welcome():
  print("이상한 나라에 오신 것을 환영합니다.")

welcome()
# Out:
# 이상한 나라에 오신 것을 환영합니다.

# %%
def draw_stars(num):
  print('*'*num)

print(draw_stars(3))
# Out:
# ***
# None

# %%
#중복되지 않는 카드 두 장을 뽀도록 빈칸을 채워보시요
clovers = ["클로버1","클로버2","클로버3"]

def sample_card(num):
  dummy_list = []
  select = random.sample(clovers, num)
  print(select)
clovers(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-b7a13f5a2ad1> in <module>
#       6   select = random.sample(clovers, num)
#       7   print(select)
# ----> 8 clovers(2)
#
# TypeError: 'list' object is not callable

# %%
# a = int(input("숫자를 맞혀보세요. (1~100"))
# guess_number = random.randint(1,100)
# while (guess_number !=a):
  # if a > guess_number:
    # print("숫자가 너무 큽니다.")
  # elif a < guess
# Out:
#   File "<ipython-input-43-3d10225d35fe>", line 6
#     elif a < guess
#                   ^
# SyntaxError: invalid syntax

# %%
#데이터 
names = ["Messi","Ronaldo","Ramos","Park","Buffon"]
positions = ["MF","DF","CF","WF","Gk"]
numbers = [10,4,7,13,1]
players=[]
for i in range(5):
  players.append([names[i],positions[i],numbers[i]])
print(players)
# Out:
# [['Messi', 'MF', 10], ['Ronaldo', 'DF', 4], ['Ramos', 'CF', 7], ['Park', 'WF', 13], ['Buffon', 'Gk', 1]]

# %%
class SoccerPlayer(object):
  def __init__(self, name, position, back_number):
    self.name = name
    self.position = position
    self.back_number = back_number
  def change_back_number(self,new_number):
    print("선수의 등번호를 %d번에서 %d번으로 변경한다."\
    %(self.back_number, new_number))
  def __str__(self):
    return "안녕하세요 제 이름은 %s입니다. \
    그리고 %s 포지션으로 활약중입니다."\
    %(self.name, self.position)

# %%
SoccerPlayer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-1e47beea35f1> in <module>
# ----> 1 SoccerPlayer()
#
# TypeError: __init__() missing 3 required positional arguments: 'name', 'position', and 'back_number'
